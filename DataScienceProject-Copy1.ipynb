# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('TERMS_FullTimeSince2005.xlsx', sheet_name='TERMS')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19917 entries, 0 to 19916
# Data columns (total 44 columns):
# EMPL_STATUS               19917 non-null object
# EMPL_SATUS_DESCR          19917 non-null object
# EFFDT                     19917 non-null datetime64[ns]
# DIVID                     19917 non-null object
# DIVISION_DESCR            19917 non-null object
# DIVISION_GROUP            19917 non-null object
# LOCATION                  19917 non-null object
# ACTION_REASON             19917 non-null object
# ACTION_REASON_DESCR       19917 non-null object
# REASON2                   19917 non-null object
# COMPA_RATIO               14548 non-null float64
# ANNUAL_RT                 19917 non-null float64
# HOURLY_RT                 19917 non-null float64
# FLSA_STATUS               19917 non-null object
# EMPL_CLASS                19917 non-null object
# MANAGER_LEVEL             19917 non-null int64
# MGR_LEVEL_DESCR           19917 non-null object
# ...

# %%
df
# Out:
#       EMPL_STATUS     EMPL_SATUS_DESCR      EFFDT DIVID  \
# 0               T           Terminated 2008-06-01   035
# 1               T           Terminated 2007-03-19   355
# 2               U  Terminated With Pay 2010-07-31  5100
# 3               T           Terminated 2007-09-14   CRB
# 4               U  Terminated With Pay 2009-01-30   355
# 5               T           Terminated 2013-03-16  5100
# 6               T           Terminated 2005-03-05   CRB
# 7               U  Terminated With Pay 2009-02-07   355
# 8               U  Terminated With Pay 2010-09-16  5100
# 9               T           Terminated 2016-11-19  5100
# 10              U  Terminated With Pay 2016-11-16  5100
# 11              U  Terminated With Pay 2011-12-16  5100
# 12              T           Terminated 2011-02-16  5100
# 13              U  Terminated With Pay 2010-07-31  5100
# 14              U  Terminated With Pay 2009-02-07   355
# 15              U  Terminated With Pay 2010-07-31  5100
# ...

# %%
df['REASON2'].value_counts()
# Out:
# VOL           11392
# INVOL          8522
# RELOCATING        3
# Name: REASON2, dtype: int64

# %%
nonrelocating = df['REASON2'] != 'RELOCATING'
df = df[nonrelocating]
df['REASON2'].value_counts()
# Out:
# VOL      11392
# INVOL     8522
# Name: REASON2, dtype: int64

# %%
g = sns.countplot(x=df['REASON2'])

# %%
vol = df['REASON2'] == 'VOL'
df[vol]['ACTION_REASON_DESCR'].value_counts()
# Out:
# Resignation                       6489
# Accepted A New Position           1897
# Personal Reasons                   667
# Relocation                         604
# Failure to Return from Leave       573
# Return to School                   225
# Voluntary Separation Program       175
# Dissatisfied w/Work Conditions     165
# Non-compete Agreement              139
# Dissatisfied with Pay              118
# Dissatisfied with Hours            101
# Dissatisfied with Supervision       86
# Health Reasons                      71
# None Given                          31
# Transportation Problems             19
# Never Started                       14
# Waived Non-Compete Agreement         9
# Dissatisfied w/Fellow Employee       7
# Refused Counter Offer                2
# Name: ACTION_REASON_DESCR, dtype: int64

# %%
invol = df['REASON2'] == "INVOL"
df[invol]['ACTION_REASON_DESCR'].value_counts()
# Out:
# Elimination of Position           3341
# Mutual Consent                     866
# Violation Of Policy                700
# Other                              537
# Unsatisfactory Performance         480
# Unavail for Wrk/Job Abandonmnt     424
# Attendance                         384
# Unable to Meet Job Requirement     331
# Unable To Meet Job Requirement     228
# Misconduct                         177
# Failure to Report w/o Notice       149
# Transition Assistance              148
# Unable To Return From Disablty     138
# Poor Or Improper Conduct           119
# Theft                              109
# Lack of Work/Layoff                 94
# Do Not Contest                      65
# Discharge                           64
# Unwilling to Meet Requirements      43
# Tardiness                           38
# Insubordination                     31
# Misstatement on Application         13
# Pending Signed Agreement            12
# Reorganization                      10
# ...

# %%
fig, ax = plt.subplots(figsize=(20,10))
sns.countplot(x= df['ACTION_REASON'], hue=df['SEX'])

# %%
fig, ax = plt.subplots(figsize=(20,6))
sns.countplot(x = df['SERVICE_YRS'], hue=df['SEX'])

# %%
fig, ax = plt.subplots(figsize=(20,6))
sns.countplot(x = df['TERM_YEAR'])

# %%
fig, ax = plt.subplots(figsize=(30,6))
sns.countplot(x = df['TERM_YEAR'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19914 entries, 0 to 19916
# Data columns (total 44 columns):
# EMPL_STATUS               19914 non-null object
# EMPL_SATUS_DESCR          19914 non-null object
# EFFDT                     19914 non-null datetime64[ns]
# DIVID                     19914 non-null object
# DIVISION_DESCR            19914 non-null object
# DIVISION_GROUP            19914 non-null object
# LOCATION                  19914 non-null object
# ACTION_REASON             19914 non-null object
# ACTION_REASON_DESCR       19914 non-null object
# REASON2                   19914 non-null object
# COMPA_RATIO               14546 non-null float64
# ANNUAL_RT                 19914 non-null float64
# HOURLY_RT                 19914 non-null float64
# FLSA_STATUS               19914 non-null object
# EMPL_CLASS                19914 non-null object
# MANAGER_LEVEL             19914 non-null int64
# MGR_LEVEL_DESCR           19914 non-null object
# ...

# %%
df.describe()
# Out:
#         COMPA_RATIO      ANNUAL_RT     HOURLY_RT  MANAGER_LEVEL       JOBCODE  \
# count  14546.000000   19914.000000  19914.000000   19914.000000  19914.000000
# mean       0.771579   53929.034750     26.041630     258.823642   1869.530632
# std        0.256014   40643.991624     19.531438     324.447612   1025.399465
# min        0.000000       0.000000      0.000000       0.000000      1.000000
# 25%        0.680000   28516.800000     13.817981       0.000000   1174.000000
# 50%        0.800000   42000.000000     20.302866       0.000000   1550.000000
# 75%        0.910000   66500.000000     31.998798     633.000000   2684.000000
# max        2.020000  612000.000000    294.230769     990.000000   4532.000000
#
#        ORIG_HIRE_YEAR     TERM_YEAR   SERVICE_YRS    BIRTH_YEAR  \
# count    19914.000000  19914.000000  19914.000000  19914.000000
# mean      2005.838204   2011.507783      4.923471   1973.108969
# std          7.856401      3.480324      6.919780     12.095021
# ...

# %%
fig, ax = plt.subplots(figsize=(15,6))
sns.countplot(x= df['DIVISION_GROUP'], hue=df['SEX'])

# %%
fig, ax = plt.subplots(figsize=(30,10))
sns.countplot(x= df['JOB_FXN'], hue=df['SEX'])

# %%
fig, ax = plt.subplots(figsize=(20,6))
sns.boxplot(x=df[invol]['ANNUAL_RT'], y = df[invol]['SERVICE_YRS'])
