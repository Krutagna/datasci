# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('TERMS_FullTimeSince2005.xlsx', sheet_name='TERMS')

# %%
#x is service years
x = df.iloc[:, [29]].values
#y is annual_rate
y = df.iloc[:, [11]].values

plt.scatter(x,y)
plt.show()

#x = np.atleast_2d(x)
#y = np.atleast_2d(y)
#x.reshape(-1,1)
#y.reshape(-1,1)

# %%
from sklearn.cross_validation import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 1)
# Out:
# /Users/krutagnapurohit/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train, y_train)

#x.reshape(-1, 1), y.reshape(-1, 1)

# Predicting the Test set results
y_pred = regressor.predict(x_test)

plt.scatter(x_train, y_train, color = 'red')
plt.plot(x_train, regressor.predict(x_train), color = 'blue')
plt.xlabel('Service Years')
plt.ylabel('Annual Salary')
plt.show()

# %%
print('Misclassified examples : %d'%(y_test != y_pred).sum())
# Out:
# Misclassified examples : 5976

# %%
from sklearn.metrics import accuracy_score
print('Accuracy: %.2f' % accuracy_score(y_test,y_pred))

#regressor.score(y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-9a2e58ed9bd4> in <module>()
#       1 from sklearn.metrics import accuracy_score
# ----> 2 print('Accuracy: %.2f' % accuracy_score(y_test,y_pred))
#       3
#       4 #regressor.score(y_test, y_pred)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     174
#     175     # Compute accuracy for each possible representation
# --> 176     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     177     if y_type.startswith('multilabel'):
#     178         differing_labels = count_nonzero(y_true - y_pred, axis=1)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py in _check_targets(y_true, y_pred)
#      86     # No metrics support "multiclass-multioutput" format
#      87     if (y_type not in ["binary", "multiclass", "multilabel-indicator"]):
# ---> 88         raise ValueError("{0} is not supported".format(y_type))
#      89
#      90     if y_type in ["binary", "multiclass"]:
#
# ValueError: continuous is not supported

# %%
#x is sex
x1 = df.iloc[:100,[1]].values
#y is reason2
y1 = df.iloc[:100,[9]].values

plt.hist2d(x1,y1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py in histogramdd(sample, bins, range, normed, weights)
#     900         # Sample is an ND-array.
# --> 901         N, D = sample.shape
#     902     except (AttributeError, ValueError):
#
# AttributeError: 'list' object has no attribute 'shape'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-77-1581395161e6> in <module>()
#       4 y1 = df.iloc[:100,[9]].values
#       5
# ----> 6 plt.hist2d(x1,y1)
#       7 plt.show()
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in hist2d(x, y, bins, range, normed, weights, cmin, cmax, hold, data, **kwargs)
#    3047         ret = ax.hist2d(x, y, bins=bins, range=range, normed=normed,
#    3048                         weights=weights, cmin=cmin, cmax=cmax, data=data,
# -> 3049                         **kwargs)
#    3050     finally:
#    3051         ax._hold = washold
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1715                     warnings.warn(msg % (label_namer, func.__name__),
#    1716                                   RuntimeWarning, stacklevel=2)
# -> 1717             return func(ax, *args, **kwargs)
#    1718         pre_doc = inner.__doc__
#    1719         if pre_doc is None:
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in hist2d(self, x, y, bins, range, normed, weights, cmin, cmax, **kwargs)
#    6450
#    6451         h, xedges, yedges = np.histogram2d(x, y, bins=bins, range=range,
# -> 6452                                            normed=normed, weights=weights)
#    6453
#    6454         if cmin is not None:
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/lib/twodim_base.py in histogram2d(x, y, bins, range, normed, weights)
#     653         xedges = yedges = asarray(bins, float)
#     654         bins = [xedges, yedges]
# --> 655     hist, edges = histogramdd([x, y], bins, range, normed, weights)
#     656     return hist, edges[0], edges[1]
#     657
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py in histogramdd(sample, bins, range, normed, weights)
#     903         # Sample is a sequence of 1D arrays.
#     904         sample = atleast_2d(sample).T
# --> 905         N, D = sample.shape
#     906
#     907     nbin = empty(D, int)
#
# ValueError: too many values to unpack (expected 2)
